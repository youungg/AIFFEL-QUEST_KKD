# %% [markdown]
# # <span style = "color:#FFFFFF; background-color: #FF99AA"> CIFAR10 딥러닝 모델</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <span style = "background-color: #FFDDE5"> 데이터 로드 및 전처리</span>
# ---
# - CIFAR10 데이터셋을 로드하고, 훈련 데이터셋에서 20%를 검증 데이터셋으로 분리합니다. 데이터셋은 **`keras.datasets`** 에서 불러올 수 있는 CIFAR10 데이터 셋을 활용합니다.
# - 데이터셋 분리 작업에서는 sklearn 라이브러리의 **`train_test_split`** 함수를 활용합니다.
# - 훈련, 검증, 테스트 데이터와 레이블 종류가 몇개인지 출력합니다.

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers
from tensorflow.keras.datasets import cifar10

# %%
# 문제 3-1: cifar10 데이터셋을 로드하고, 훈련 데이터셋에서 20%를 검증 데이터셋으로 분리합니다.
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full,
                                                  test_size=0.2)


# 훈련, 검증, 테스트 데이터와 레이블 종류가 몇개인지 출력합니다.
print("전체 학습 데이터: {} 레이블: {}".format(x_train_full.shape, y_train_full.shape))
print("학습 데이터: {} 레이블: {}".format(x_train.shape, y_train.shape))
print("검증 데이터: {} 레이블: {}".format(x_val.shape, y_val.shape))
print("테스트 데이터: {} 레이블: {}".format(x_test.shape, y_test.shape))
# Out:
# 전체 학습 데이터: (50000, 32, 32, 3) 레이블: (50000, 1)
# 학습 데이터: (40000, 32, 32, 3) 레이블: (40000, 1)
# 검증 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)
# 테스트 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)

# %% [markdown]
# - class_name 변수를 만들어 cifar10의 분류에 해당하는 'airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'를 담습니다.

# %%
# cifar10의 분류에 해당하는 'airplane', 'automobile', 'bird', 'cat', 'deer', 
# 'dog', 'frog', 'horse', 'ship', 'truck'를 class_name으로 정의합니다.
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# - 데이터 중 샘플 하나를 시각화해보고, 데이터의 형태를 확인해봅니다.

# %%
# 훈련 데이터의 0번째인 x_train[0]를 이미지로 시각화합니다.
plt.style.use('seaborn-white')

plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.show()

# %%
# 훈련, 검증, 테스트 데이터의 형태(shape)을 출력합니다.
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# - 데이터의 형태를 변형하여 모델이 잘 학습할 수 있게끔 해줍니다.

# %%
# 문제 3-2: 훈련, 검증, 테스트 데이터의 형태(shape)을 32 * 32 * 3 = 3072로 변형합니다.
x_train = x_train.reshape(-1, 32 * 32 * 3)
x_val = x_val.reshape(-1, 32 * 32 * 3)
x_test = x_test.reshape(-1, 32 * 32 * 3)

print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 3072)
# (10000, 3072)
# (10000, 3072)

# %%
# 훈련, 검증, 테스트 데이터를 255로 나누어 0~1 사이의 값으로 변환합니다.
x_train = x_train / 255.
x_val = x_val / 255.
x_test = x_test / 255.

# %% [markdown]
# ### <span style = "background-color: #FFDDE5"> 모델 구성 및 컴파일</span>
# ---
# - BatchNormalization과 Dropout을 적용하여 빠르게 학습하면서 과대적합을 방지하고, 10개의 이미지를 분류하는 딥러닝 모델을 구성합니다.
# ![image.png](attachment:image.png)

# %%
# 문제 3-3: BatchNormalization과 Dropout을 적용하여 빠른 학습과 과대적합을 방지하고,
# 10개의 이미지를 분류하는 딥러닝 모델을 구성합니다.
model = models.Sequential()

### 비교대조의 편의를 위하여 제시 모델 구조도와 동일한 레이어명 사용
model.add(layers.Input(shape=(3072, ), name='input_15'))

model.add(layers.Dense(2048, name='dense_91'))
model.add(layers.BatchNormalization(name='batch_normalization_66'))
model.add(layers.Activation('relu', name='activation_66')) 
model.add(layers.Dropout(0.5, name='dropout_66'))

model.add(layers.Dense(1024, name='dense_92'))
model.add(layers.BatchNormalization(name='batch_normalization_67'))
model.add(layers.Activation('relu', name='activation_67')) 
model.add(layers.Dropout(0.5, name='dropout_67'))

model.add(layers.Dense(512, name='dense_93'))
model.add(layers.BatchNormalization(name='batch_normalization_68'))
model.add(layers.Activation('relu', name='activation_68')) 
model.add(layers.Dropout(0.5, name='dropout_68'))

model.add(layers.Dense(10, activation='softmax', name='dense_94'))



model.compile(loss='sparse_categorical_crossentropy',
              optimizer='SGD',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_91 (Dense)             (None, 2048)              6293504
# _________________________________________________________________
# batch_normalization_66 (Batc (None, 2048)              8192
# _________________________________________________________________
# activation_66 (Activation)   (None, 2048)              0
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_92 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_67 (Batc (None, 1024)              4096
# _________________________________________________________________
# activation_67 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_93 (Dense)             (None, 512)               524800
# _________________________________________________________________
# batch_normalization_68 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_68 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_94 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 8,935,946
# Trainable params: 8,928,778
# Non-trainable params: 7,168
# _________________________________________________________________

# %%
from tensorflow.keras import utils
utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ### <span style = "background-color: #FFDDE5"> 모델 학습</span>
# ---
# - ModelCheckpoint와 EarlyStopping 콜백 함수를 적용하여 모델 학습을 진행합니다.

# %%
# 문제 3-4: ModelCheckpoint와 EarlyStopping 콜백 함수를 적용하여 모델 학습을 진행합니다.
from tensorflow.keras import callbacks
check_point_cb = callbacks.ModelCheckpoint('keras_cifar10_model.h5', save_best_only=True)
early_stopping_cb = callbacks.EarlyStopping(patience=10, monitor='val_loss',
                                            restore_best_weights=True)

history = model.fit(x_train, y_train,
                    epochs=1000, ### 제시된 시각화 그래프는 약 800 epochs 학습을 수행하였으므로 동일하게 진행
                    batch_size=512,
                    validation_data=(x_val, y_val),
                    callbacks=[check_point_cb, early_stopping_cb])
# Out:
# Epoch 1/1000
# 79/79 [==============================] - 3s 18ms/step - loss: 2.6709 - accuracy: 0.1593 - val_loss: 2.1696 - val_accuracy: 0.1695
# Epoch 2/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 2.3755 - accuracy: 0.2209 - val_loss: 2.0185 - val_accuracy: 0.2640
# Epoch 3/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 2.2489 - accuracy: 0.2521 - val_loss: 1.9014 - val_accuracy: 0.3145
# Epoch 4/1000
# 79/79 [==============================] - 1s 17ms/step - loss: 2.1627 - accuracy: 0.2729 - val_loss: 1.8254 - val_accuracy: 0.3473
# Epoch 5/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 2.0956 - accuracy: 0.2833 - val_loss: 1.7737 - val_accuracy: 0.3664
# Epoch 6/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 2.0382 - accuracy: 0.2964 - val_loss: 1.7274 - val_accuracy: 0.3799
# Epoch 7/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 2.0071 - accuracy: 0.3066 - val_loss: 1.7108 - val_accuracy: 0.3886
# Epoch 8/1000
# 79/79 [==============================] - 1s 12ms/step - loss: 1.9654 - accuracy: 0.3145 - val_loss: 1.6869 - val_accuracy: 0.3954
# Epoch 9/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.9347 - accuracy: 0.3228 - val_loss: 1.6720 - val_accuracy: 0.4007
# Epoch 10/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.9008 - accuracy: 0.3337 - val_loss: 1.6566 - val_accuracy: 0.4044
# Epoch 11/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.8795 - accuracy: 0.3385 - val_loss: 1.6563 - val_accuracy: 0.4042
# Epoch 12/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.8620 - accuracy: 0.3415 - val_loss: 1.6472 - val_accuracy: 0.4081
# Epoch 13/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.8340 - accuracy: 0.3502 - val_loss: 1.6373 - val_accuracy: 0.4111
# Epoch 14/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.8097 - accuracy: 0.3552 - val_loss: 1.6395 - val_accuracy: 0.4105
# Epoch 15/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.7940 - accuracy: 0.3610 - val_loss: 1.6269 - val_accuracy: 0.4172
# Epoch 16/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.7806 - accuracy: 0.3625 - val_loss: 1.6299 - val_accuracy: 0.4154
# Epoch 17/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.7640 - accuracy: 0.3672 - val_loss: 1.6138 - val_accuracy: 0.4178
# Epoch 18/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.7511 - accuracy: 0.3729 - val_loss: 1.6055 - val_accuracy: 0.4212
# Epoch 19/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.7371 - accuracy: 0.3770 - val_loss: 1.5970 - val_accuracy: 0.4254
# Epoch 20/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.7306 - accuracy: 0.3792 - val_loss: 1.5849 - val_accuracy: 0.4285
# Epoch 21/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.7222 - accuracy: 0.3852 - val_loss: 1.5866 - val_accuracy: 0.4266
# Epoch 22/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.7084 - accuracy: 0.3867 - val_loss: 1.5874 - val_accuracy: 0.4274
# Epoch 23/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6956 - accuracy: 0.3920 - val_loss: 1.5908 - val_accuracy: 0.4237
# Epoch 24/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6877 - accuracy: 0.3953 - val_loss: 1.5832 - val_accuracy: 0.4301
# Epoch 25/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6841 - accuracy: 0.3966 - val_loss: 1.5636 - val_accuracy: 0.4353
# Epoch 26/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6737 - accuracy: 0.3990 - val_loss: 1.5518 - val_accuracy: 0.4380
# Epoch 27/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6613 - accuracy: 0.3999 - val_loss: 1.5547 - val_accuracy: 0.4393
# Epoch 28/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6572 - accuracy: 0.4062 - val_loss: 1.5693 - val_accuracy: 0.4338
# Epoch 29/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6437 - accuracy: 0.4064 - val_loss: 1.5569 - val_accuracy: 0.4391
# Epoch 30/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6419 - accuracy: 0.4085 - val_loss: 1.5405 - val_accuracy: 0.4441
# Epoch 31/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.6281 - accuracy: 0.4148 - val_loss: 1.5481 - val_accuracy: 0.4435
# Epoch 32/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6290 - accuracy: 0.4151 - val_loss: 1.5394 - val_accuracy: 0.4441
# Epoch 33/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6190 - accuracy: 0.4156 - val_loss: 1.5407 - val_accuracy: 0.4419
# Epoch 34/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6154 - accuracy: 0.4191 - val_loss: 1.5334 - val_accuracy: 0.4443
# Epoch 35/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.6092 - accuracy: 0.4212 - val_loss: 1.5373 - val_accuracy: 0.4434
# Epoch 36/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5993 - accuracy: 0.4253 - val_loss: 1.5237 - val_accuracy: 0.4483
# Epoch 37/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5966 - accuracy: 0.4273 - val_loss: 1.5370 - val_accuracy: 0.4438
# Epoch 38/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5923 - accuracy: 0.4294 - val_loss: 1.5091 - val_accuracy: 0.4539
# Epoch 39/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5883 - accuracy: 0.4314 - val_loss: 1.5269 - val_accuracy: 0.4479
# Epoch 40/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5862 - accuracy: 0.4294 - val_loss: 1.5152 - val_accuracy: 0.4525
# Epoch 41/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5735 - accuracy: 0.4365 - val_loss: 1.5042 - val_accuracy: 0.4553
# Epoch 42/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5728 - accuracy: 0.4385 - val_loss: 1.5137 - val_accuracy: 0.4535
# Epoch 43/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5678 - accuracy: 0.4360 - val_loss: 1.5130 - val_accuracy: 0.4533
# Epoch 44/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5637 - accuracy: 0.4383 - val_loss: 1.4987 - val_accuracy: 0.4564
# Epoch 45/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5593 - accuracy: 0.4421 - val_loss: 1.4950 - val_accuracy: 0.4618
# Epoch 46/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5515 - accuracy: 0.4409 - val_loss: 1.4898 - val_accuracy: 0.4585
# Epoch 47/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5494 - accuracy: 0.4448 - val_loss: 1.5032 - val_accuracy: 0.4547
# Epoch 48/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5444 - accuracy: 0.4439 - val_loss: 1.4829 - val_accuracy: 0.4663
# Epoch 49/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5409 - accuracy: 0.4457 - val_loss: 1.4855 - val_accuracy: 0.4611
# Epoch 50/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5335 - accuracy: 0.4495 - val_loss: 1.4596 - val_accuracy: 0.4703
# Epoch 51/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5320 - accuracy: 0.4471 - val_loss: 1.4716 - val_accuracy: 0.4643
# Epoch 52/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5281 - accuracy: 0.4523 - val_loss: 1.4668 - val_accuracy: 0.4680
# Epoch 53/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5255 - accuracy: 0.4523 - val_loss: 1.4672 - val_accuracy: 0.4708
# Epoch 54/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5240 - accuracy: 0.4532 - val_loss: 1.4974 - val_accuracy: 0.4589
# Epoch 55/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5157 - accuracy: 0.4584 - val_loss: 1.4581 - val_accuracy: 0.4739
# Epoch 56/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5166 - accuracy: 0.4534 - val_loss: 1.4618 - val_accuracy: 0.4717
# Epoch 57/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5116 - accuracy: 0.4553 - val_loss: 1.4569 - val_accuracy: 0.4739
# Epoch 58/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.5059 - accuracy: 0.4613 - val_loss: 1.4699 - val_accuracy: 0.4705
# Epoch 59/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5018 - accuracy: 0.4629 - val_loss: 1.4672 - val_accuracy: 0.4713
# Epoch 60/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4954 - accuracy: 0.4639 - val_loss: 1.4613 - val_accuracy: 0.4728
# Epoch 61/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4948 - accuracy: 0.4631 - val_loss: 1.4633 - val_accuracy: 0.4700
# Epoch 62/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4908 - accuracy: 0.4669 - val_loss: 1.4431 - val_accuracy: 0.4796
# Epoch 63/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4884 - accuracy: 0.4648 - val_loss: 1.4481 - val_accuracy: 0.4766
# Epoch 64/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4819 - accuracy: 0.4683 - val_loss: 1.4503 - val_accuracy: 0.4756
# Epoch 65/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4815 - accuracy: 0.4678 - val_loss: 1.4601 - val_accuracy: 0.4727
# Epoch 66/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4768 - accuracy: 0.4692 - val_loss: 1.4602 - val_accuracy: 0.4698
# Epoch 67/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4766 - accuracy: 0.4688 - val_loss: 1.4371 - val_accuracy: 0.4810
# Epoch 68/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4715 - accuracy: 0.4719 - val_loss: 1.4478 - val_accuracy: 0.4786
# Epoch 69/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4678 - accuracy: 0.4701 - val_loss: 1.4442 - val_accuracy: 0.4761
# Epoch 70/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4661 - accuracy: 0.4742 - val_loss: 1.4544 - val_accuracy: 0.4753
# Epoch 71/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4650 - accuracy: 0.4746 - val_loss: 1.4324 - val_accuracy: 0.4840
# Epoch 72/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4619 - accuracy: 0.4762 - val_loss: 1.4122 - val_accuracy: 0.4891
# Epoch 73/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4520 - accuracy: 0.4773 - val_loss: 1.4179 - val_accuracy: 0.4857
# Epoch 74/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4555 - accuracy: 0.4794 - val_loss: 1.4203 - val_accuracy: 0.4856
# Epoch 75/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4480 - accuracy: 0.4790 - val_loss: 1.4119 - val_accuracy: 0.4912
# Epoch 76/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4478 - accuracy: 0.4787 - val_loss: 1.4322 - val_accuracy: 0.4835
# Epoch 77/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4441 - accuracy: 0.4818 - val_loss: 1.4170 - val_accuracy: 0.4908
# Epoch 78/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4405 - accuracy: 0.4850 - val_loss: 1.4218 - val_accuracy: 0.4914
# Epoch 79/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4387 - accuracy: 0.4840 - val_loss: 1.4167 - val_accuracy: 0.4902
# Epoch 80/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4397 - accuracy: 0.4823 - val_loss: 1.4259 - val_accuracy: 0.4856
# Epoch 81/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4387 - accuracy: 0.4848 - val_loss: 1.4343 - val_accuracy: 0.4851
# Epoch 82/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4343 - accuracy: 0.4851 - val_loss: 1.4042 - val_accuracy: 0.4949
# Epoch 83/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4288 - accuracy: 0.4882 - val_loss: 1.4000 - val_accuracy: 0.4982
# Epoch 84/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4274 - accuracy: 0.4879 - val_loss: 1.3947 - val_accuracy: 0.5003
# Epoch 85/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4236 - accuracy: 0.4886 - val_loss: 1.3931 - val_accuracy: 0.4994
# Epoch 86/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4189 - accuracy: 0.4911 - val_loss: 1.3993 - val_accuracy: 0.4979
# Epoch 87/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4193 - accuracy: 0.4897 - val_loss: 1.4021 - val_accuracy: 0.4931
# Epoch 88/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4109 - accuracy: 0.4914 - val_loss: 1.3977 - val_accuracy: 0.4965
# Epoch 89/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4090 - accuracy: 0.4949 - val_loss: 1.3824 - val_accuracy: 0.5025
# Epoch 90/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4088 - accuracy: 0.4960 - val_loss: 1.3831 - val_accuracy: 0.5012
# Epoch 91/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.4045 - accuracy: 0.4961 - val_loss: 1.3908 - val_accuracy: 0.5018
# Epoch 92/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4063 - accuracy: 0.4951 - val_loss: 1.3838 - val_accuracy: 0.5042
# Epoch 93/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3959 - accuracy: 0.4972 - val_loss: 1.4191 - val_accuracy: 0.4955
# Epoch 94/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3939 - accuracy: 0.4981 - val_loss: 1.3888 - val_accuracy: 0.4996
# Epoch 95/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3943 - accuracy: 0.4967 - val_loss: 1.3812 - val_accuracy: 0.5038
# Epoch 96/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3937 - accuracy: 0.4976 - val_loss: 1.4156 - val_accuracy: 0.4935
# Epoch 97/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3887 - accuracy: 0.5000 - val_loss: 1.3771 - val_accuracy: 0.5026
# Epoch 98/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3856 - accuracy: 0.5010 - val_loss: 1.3724 - val_accuracy: 0.5063
# Epoch 99/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3851 - accuracy: 0.5008 - val_loss: 1.4215 - val_accuracy: 0.4929
# Epoch 100/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3882 - accuracy: 0.5017 - val_loss: 1.3774 - val_accuracy: 0.5020
# Epoch 101/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3837 - accuracy: 0.5013 - val_loss: 1.3843 - val_accuracy: 0.5005
# Epoch 102/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3787 - accuracy: 0.5020 - val_loss: 1.3813 - val_accuracy: 0.5014
# Epoch 103/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3770 - accuracy: 0.5044 - val_loss: 1.3736 - val_accuracy: 0.5068
# Epoch 104/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3692 - accuracy: 0.5092 - val_loss: 1.3916 - val_accuracy: 0.4991
# Epoch 105/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3686 - accuracy: 0.5088 - val_loss: 1.3716 - val_accuracy: 0.5072
# Epoch 106/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3698 - accuracy: 0.5095 - val_loss: 1.3708 - val_accuracy: 0.5064
# Epoch 107/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3609 - accuracy: 0.5093 - val_loss: 1.3562 - val_accuracy: 0.5105
# Epoch 108/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3579 - accuracy: 0.5127 - val_loss: 1.3610 - val_accuracy: 0.5100
# Epoch 109/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3558 - accuracy: 0.5120 - val_loss: 1.3713 - val_accuracy: 0.5071
# Epoch 110/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3587 - accuracy: 0.5118 - val_loss: 1.3616 - val_accuracy: 0.5093
# Epoch 111/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3533 - accuracy: 0.5135 - val_loss: 1.3501 - val_accuracy: 0.5126
# Epoch 112/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3493 - accuracy: 0.5124 - val_loss: 1.3922 - val_accuracy: 0.5020
# Epoch 113/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3475 - accuracy: 0.5139 - val_loss: 1.3595 - val_accuracy: 0.5115
# Epoch 114/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3444 - accuracy: 0.5165 - val_loss: 1.3655 - val_accuracy: 0.5107
# Epoch 115/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3479 - accuracy: 0.5164 - val_loss: 1.3798 - val_accuracy: 0.5086
# Epoch 116/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3455 - accuracy: 0.5162 - val_loss: 1.3438 - val_accuracy: 0.5126
# Epoch 117/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3411 - accuracy: 0.5181 - val_loss: 1.3586 - val_accuracy: 0.5118
# Epoch 118/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3394 - accuracy: 0.5172 - val_loss: 1.3895 - val_accuracy: 0.5044
# Epoch 119/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3361 - accuracy: 0.5189 - val_loss: 1.3506 - val_accuracy: 0.5132
# Epoch 120/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3340 - accuracy: 0.5208 - val_loss: 1.3499 - val_accuracy: 0.5178
# Epoch 121/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3281 - accuracy: 0.5240 - val_loss: 1.3571 - val_accuracy: 0.5124
# Epoch 122/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3256 - accuracy: 0.5229 - val_loss: 1.3299 - val_accuracy: 0.5217
# Epoch 123/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3225 - accuracy: 0.5268 - val_loss: 1.3801 - val_accuracy: 0.5039
# Epoch 124/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3200 - accuracy: 0.5255 - val_loss: 1.3567 - val_accuracy: 0.5152
# Epoch 125/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3201 - accuracy: 0.5239 - val_loss: 1.3554 - val_accuracy: 0.5117
# Epoch 126/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3212 - accuracy: 0.5277 - val_loss: 1.3418 - val_accuracy: 0.5177
# Epoch 127/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3206 - accuracy: 0.5266 - val_loss: 1.3367 - val_accuracy: 0.5174
# Epoch 128/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3130 - accuracy: 0.5296 - val_loss: 1.3471 - val_accuracy: 0.5168
# Epoch 129/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3112 - accuracy: 0.5272 - val_loss: 1.3389 - val_accuracy: 0.5178
# Epoch 130/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3052 - accuracy: 0.5281 - val_loss: 1.4147 - val_accuracy: 0.5063
# Epoch 131/1000
# 79/79 [==============================] - 1s 11ms/step - loss: 1.3066 - accuracy: 0.5322 - val_loss: 1.3626 - val_accuracy: 0.5134
# Epoch 132/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 1.3053 - accuracy: 0.5300 - val_loss: 1.3384 - val_accuracy: 0.5182

# %% [markdown]
# - 학습 히스토리의 **`loss`**, **`val_loss`**, **`accuracy`**, **`val_accuracy`** 를 차트로 시각화합니다.
# ![image.png](attachment:image.png)

# %%
# 문제 3-5: 학습 히스토리의 `loss`, `val_loss`, `accuracy`, `val_accuracy`를 차트로 시각화합니다.
history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

### train_loss, val_loss 비교를 위한 그래프 작성
ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

### train_accuracy, val_accuracy 비교를 위한 그래프 작성
ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %% [markdown]
# ### <span style = "background-color: #FFDDE5"> 모델 평가 및 예측</span>
# ---
# - 테스트 데이터셋을 이용해 모델을 평가합니다.

# %%
# 테스트 데이터셋을 이용해 모델을 평가합니다.
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.3245 - accuracy: 0.5226
# [1.32450270652771, 0.522599995136261]

# %% [markdown]
# ---
# **회고록**
# batch normalization, dropout이 적용된 3개의 Dense 레이어와 softmax 함수가 적용된 1개의 Dense 레이어로 구성된 모델을 이용한 학습 결과, 제시된 시각화 그래프와 유사한 양상을 보였다.
# epochs를 거듭할수록 loss는 줄어들고 accuracy는 늘어나는 양상을 보였으나, epochs 약 130 이상부터는 그 변동폭이 미미하여 early stopping을 통해 training을 사전에 종료하였다.
#
# 이전까지의 프로젝트는 제시된 학습 모델 코드를 그대로 활용하는 방식으로 TensorFlow 프로그래밍에 관한 이해도를 높이기 어려웠는데,
# 이번 프로젝트에서는 간단한 구조의 모델나마 직접 코드를 작성하고 구현해볼 수 있어서 굉장히 뿌듯했다 🥹
